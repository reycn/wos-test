# %%
# !pip install pkgman
# !pip install git+https://github.com/clarivate/wosstarter_python_client.git

# %%
import clarivate.wos_starter.client
from pkgman import include

include(["pandas", "requests", "numpy", "tqdm", "os", "rich"])
pd = pandas
req = requests
np = numpy
os = os
pp = rich.print
tqdm = tqdm.tqdm
# Out:
# [pkgman] Installing and importing ['pandas', 'requests', 'numpy', 'tqdm', 'os', 'rich']...
# [pkgman] 6 packages have been imported.

# %%
config_file = "../config/starter.key"
if os.path.exists(config_file):
    with open(config_file, "r") as f:
        api_key = f.read().strip()
    pp("[green bold]API key successfully loaded from config file.[/green bold]")
else:
    api_key = input("Please enter your API key: ")
    with open(config_file, "w") as f:
        f.write(api_key)
        pp("[green bold]API key saved to config file.[/green bold]")
# Out:
# API key successfully loaded from config file.

# %%
import time
import clarivate.wos_starter.client
from clarivate.wos_starter.client.rest import ApiException
from pprint import pprint

# Defining the host is optional and defaults to http://api.clarivate.com/apis/wos-starter/v1
# See configuration.py for a list of all supported configuration parameters.
configuration = clarivate.wos_starter.client.Configuration(
    host="https://api.clarivate.com/apis/wos-starter/v1"
)

# The client must configure the authentication and authorization parameters
# in accordance with the API server security policy.
# Examples for each auth method are provided below, use the example that
# satisfies your auth use case.

# Configure API key authorization: ClarivateApiKeyAuth
configuration.api_key["ClarivateApiKeyAuth"] = api_key
""
# Uncomment below to setup prefix (e.g. Bearer) for API key, if needed
# configuration.api_key_prefix['ClarivateApiKeyAuth'] = 'Bearer'


# Enter a context with an instance of the API client
with clarivate.wos_starter.client.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = clarivate.wos_starter.client.DocumentsApi(api_client)
    q = "PY=2020"  # str | Web of Science advanced [advanced search query builder](https://webofscience.help.clarivate.com/en-us/Content/advanced-search.html). The supported field tags are listed in description.
    db = "WOS"
    limit = 50  # int | set the limit of records on the page (1-50) (optional) (default to 10)
    page = 1  # int | set the result page (optional) (default to 1)
    sort_field = "LD+D"  # str | Order by field(s). Field name and order by clause separated by '+', use A for ASC and D for DESC, ex: PY+D. Multiple values are separated by comma. Supported fields:  * **LD** - Load Date * **PY** - Publication Year * **RS** - Relevance * **TC** - Times Cited  (optional)
    modified_time_span = None  # str | Defines a date range in which the results were most recently modified. Beginning and end dates must be specified in the yyyy-mm-dd format separated by '+' or ' ', e.g. 2023-01-01+2023-12-31. This parameter is not compatible with the all databases search, i.e. db=WOK is not compatible with this parameter. (optional)
    tc_modified_time_span = None  # str | Defines a date range in which times cited counts were modified. Beginning and end dates must be specified in the yyyy-mm-dd format separated by '+' or ' ', e.g. 2023-01-01+2023-12-31. This parameter is not compatible with the all databases search, i.e. db=WOK is not compatible with this parameter. (optional)
    detail = None  # str | it will returns the full data by default, if detail=short it returns the limited data (optional)

    try:
        # Query Web of Science documents
        api_response = api_instance.documents_get(
            q,
            db=db,
            limit=limit,
            page=page,
            sort_field=sort_field,
            modified_time_span=modified_time_span,
            tc_modified_time_span=tc_modified_time_span,
            detail=detail,
        )
        print("The response of DocumentsApi->documents_get:\n")
        pp(api_response)
    except ApiException as e:
        print("Exception when calling DocumentsApi->documents_get: %s\n" % e)
# Out:
# The response of DocumentsApi->documents_get:
# DocumentsList(
#     metadata=Metadata(page=1, limit=50, total=3569892),
#     hits=[
#         Document(
#             uid='WOS:001422060500001',
#             title='AWAKE ENDOSCOPY SUGGESTS BENEFIT OF COMBINATION THERAPY WITH HNS STIMULATION',
#             types=['Abstract'],
#             source_types=['Meeting Abstract'],
#             source=DocumentSource(
#                 source_title='CHEST',
#                 publish_year=2020,
#                 publish_month='OCT',
#                 volume='166',
#                 issue='4',
#                 supplement='S',
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range='6205A-6206A', begin='6205A', end='6206A', count=2)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Scott, Dylan',
#                         wos_standard='Scott, D',
#                         researcher_id='DPV-9126-2022'
#                     ),
#                     AuthorName(
#                         display_name='Arunthari, Vichaya',
#                         wos_standard='Arunthari, V',
#                         researcher_id='CED-0303-2022'
#                     ),
#                     AuthorName(
#                         display_name='Colaco, Brendon',
#                         wos_standard='Colaco, B',
#                         researcher_id='ERT-5634-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=None,
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001422060500001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles=None,
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001422060500001&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001422060500001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=0)],
#             identifiers=DocumentIdentifiers(
#                 doi='10.1016/j.chest.2024.06.3674',
#                 issn='0012-3692',
#                 eissn='1931-3543',
#                 isbn=None,
#                 eisbn=None,
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207690601031',
#             title='Labelling unlabelled videos from scratch with multi-modal self-supervision',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=12)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Asano, Yuki M.',
#                         wos_standard='Asano, YM',
#                         researcher_id='AAQ-1283-2021'
#                     ),
#                     AuthorName(
#                         display_name='Patrick, Mandela',
#                         wos_standard='Patrick, M',
#                         researcher_id='DLI-4588-2022'
#                     ),
#                     AuthorName(
#                         display_name='Rupprecht, Christian',
#                         wos_standard='Rupprecht, C',
#                         researcher_id='ABF-7744-2021'
#                     ),
#                     AuthorName(
#                         display_name='Vedaldi, Andrea',
#                         wos_standard='Vedaldi, A',
#                         researcher_id='EAG-1349-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207690601031&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207690601031&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207690601031&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207690601031&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=57)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207690605018',
#             title='Self-Distillation Amplifies Regularization in Hilbert Space',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=11)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Mobahi, Hossein',
#                         wos_standard='Mobahi, H',
#                         researcher_id='DGX-5361-2022'
#                     ),
#                     AuthorName(
#                         display_name='Farajtabar, Mehrdad',
#                         wos_standard='Farajtabar, M',
#                         researcher_id='EUF-0894-2022'
#                     ),
#                     AuthorName(
#                         display_name='Bartlett, Peter L.',
#                         wos_standard='Bartlett, PL',
#                         researcher_id='JAV-5594-2023'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207690605018&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207690605018&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207690605018&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207690605018&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=46)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207696401042',
#             title='LAPAR: Linearly-Assembled Pixel-Adaptive Regression Network for Single Image Super-Resolution
# and Beyond',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=13)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(display_name='Li, Wenbo', wos_standard='Li, WB', researcher_id='MQJ-3027-2025'),
#                     AuthorName(display_name='Zhou, Kun', wos_standard='Zhou, K', researcher_id='G-1249-2010'),
#                     AuthorName(display_name='Qi, Lu', wos_standard='Qi, L', researcher_id='IGY-7589-2023'),
#                     AuthorName(
#                         display_name='Jiang, Nianjuan',
#                         wos_standard='Jiang, NJ',
#                         researcher_id='FBF-2569-2022'
#                     ),
#                     AuthorName(display_name='Lu, Jiangbo', wos_standard='Lu, JB', researcher_id='JEP-0461-2023'),
#                     AuthorName(display_name='Jia, Jiaya', wos_standard='Jia, JY', researcher_id='I-3251-2012')
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207696401042&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207696401042&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207696401042&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207696401042&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=70)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207696402028',
#             title='<i>LoopReg</i>: Self-supervised Learning of Implicit Surface Correspondences, Pose and Shape for
# 3D Human Mesh Registration',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=14)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Bhatnagar, Bharat Lal',
#                         wos_standard='Bhatnagar, BL',
#                         researcher_id='CGM-6694-2022'
#                     ),
#                     AuthorName(
#                         display_name='Sminchisescu, Cristian',
#                         wos_standard='Sminchisescu, C',
#                         researcher_id='DVM-3103-2022'
#                     ),
#                     AuthorName(
#                         display_name='Theobalt, Christian',
#                         wos_standard='Theobalt, C',
#                         researcher_id='DXR-0274-2022'
#                     ),
#                     AuthorName(
#                         display_name='Pons-Moll, Gerard',
#                         wos_standard='Pons-Moll, G',
#                         researcher_id='AAF-8845-2019'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207696402028&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207696402028&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207696402028&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207696402028&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=1)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001181866502003',
#             title='LEGAL-BERT: The Muppets straight out of Law School',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='FINDINGS OF THE ASSOCIATION FOR COMPUTATIONAL LINGUISTICS, EMNLP 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume=None,
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=7)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Chalkidis, Ilias',
#                         wos_standard='Chalkidis, I',
#                         researcher_id='GBG-2389-2022'
#                     ),
#                     AuthorName(
#                         display_name='Fergadiotis, Manos',
#                         wos_standard='Fergadiotis, M',
#                         researcher_id='EUF-0710-2022'
#                     ),
#                     AuthorName(
#                         display_name='Malakasiotis, Prodromos',
#                         wos_standard='Malakasiotis, P',
#                         researcher_id='DEI-9166-2022'
#                     ),
#                     AuthorName(
#                         display_name='Aletras, Nikolaos',
#                         wos_standard='Aletras, N',
#                         researcher_id='DSU-2363-2022'
#                     ),
#                     AuthorName(
#                         display_name='Androutsopoulos, Ion',
#                         wos_standard='Androutsopoulos, I',
#                         researcher_id='EKC-1804-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Cohn, T'),
#                     OtherName(display_name='He, Y'),
#                     OtherName(display_name='Liu, Y')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001181866502003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001181866502003&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001181866502003&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001181866502003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=93)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn=None,
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-952148-90-3',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207690601048',
#             title='Learning Differentiable Programs with Admissible Neural Heuristics',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=13)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Shah, Ameesh',
#                         wos_standard='Shah, A',
#                         researcher_id='FVN-0822-2022'
#                     ),
#                     AuthorName(display_name='Zhan, Eric', wos_standard='Zhan, E', researcher_id='EIW-2545-2022'),
#                     AuthorName(
#                         display_name='Sun, Jennifer J.',
#                         wos_standard='Sun, JJ',
#                         researcher_id='LGL-3783-2024'
#                     ),
#                     AuthorName(
#                         display_name='Verma, Abhinav',
#                         wos_standard='Verma, A',
#                         researcher_id='MRB-5751-2025'
#                     ),
#                     AuthorName(display_name='Yue, Yisong', wos_standard='Yue, YS', researcher_id='FXI-7549-2022'),
#                     AuthorName(
#                         display_name='Chaudhuri, Swarat',
#                         wos_standard='Chaudhuri, S',
#                         researcher_id='JBF-8296-2023'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207690601048&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207690601048&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207690601048&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207690601048&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=1)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207696400035',
#             title='Hard Negative Mixing for Contrastive Learning',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=12)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Kalantidis, Yannis',
#                         wos_standard='Kalantidis, Y',
#                         researcher_id='FCF-9705-2022'
#                     ),
#                     AuthorName(
#                         display_name='Sariyildiz, Mert Bulent',
#                         wos_standard='Sariyildiz, MB',
#                         researcher_id='DPX-9121-2022'
#                     ),
#                     AuthorName(display_name='Pion, Noe', wos_standard='Pion, N', researcher_id='FQO-0338-2022'),
#                     AuthorName(
#                         display_name='Weinzaepfel, Philippe',
#                         wos_standard='Weinzaepfel, P',
#                         researcher_id='GJO-4020-2022'
#                     ),
#                     AuthorName(
#                         display_name='Larlus, Diane',
#                         wos_standard='Larlus, D',
#                         researcher_id='FJZ-9170-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207696400035&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207696400035&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207696400035&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207696400035&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=236)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207690603015',
#             title='Neutralizing Self-Selection Bias in Sampling for Sortition',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=12)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Flanigan, Bailey',
#                         wos_standard='Flanigan, B',
#                         researcher_id='CQQ-4876-2022'
#                     ),
#                     AuthorName(display_name='Golz, Paul', wos_standard='Golz, P', researcher_id=None),
#                     AuthorName(
#                         display_name='Gupta, Anupam',
#                         wos_standard='Gupta, A',
#                         researcher_id='KGB-9101-2024'
#                     ),
#                     AuthorName(
#                         display_name='Procaccia, Ariel D.',
#                         wos_standard='Procaccia, AD',
#                         researcher_id='GBR-5440-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207690603015&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207690603015&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207690603015&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207690603015&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=2)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207696403077',
#             title='Parameterized Explainer for Graph Neural Network',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=12)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Luo, Dongsheng',
#                         wos_standard='Luo, DS',
#                         researcher_id='HFL-1909-2022'
#                     ),
#                     AuthorName(display_name='Cheng, Wei', wos_standard='Cheng, W', researcher_id='KJE-9207-2024'),
#                     AuthorName(display_name='Xu, Dongkuan', wos_standard='Xu, DK', researcher_id='IAM-2866-2023'),
#                     AuthorName(display_name='Yu, Wenchao', wos_standard='Yu, WC', researcher_id='GAZ-3778-2022'),
#                     AuthorName(display_name='Zong, Bo', wos_standard='Zong, B', researcher_id='IIR-3301-2023'),
#                     AuthorName(
#                         display_name='Chen, Haifeng',
#                         wos_standard='Chen, HF',
#                         researcher_id='GSM-9693-2022'
#                     ),
#                     AuthorName(
#                         display_name='Zhang, Xiang',
#                         wos_standard='Zhang, X',
#                         researcher_id='GMC-4128-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207696403077&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207696403077&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207696403077&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207696403077&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=160)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207696405029',
#             title='Sampling-Decomposable Generative Adversarial Recommender',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=11)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(display_name='Jin, Binbin', wos_standard='Jin, BB', researcher_id='GBN-4314-2022'),
#                     AuthorName(display_name='Lian, Defu', wos_standard='Lian, DF', researcher_id='AFN-4573-2022'),
#                     AuthorName(display_name='Liu, Zheng', wos_standard='Liu, Z', researcher_id='LBE-0654-2024'),
#                     AuthorName(display_name='Liu, Qi', wos_standard='Liu, Q', researcher_id='HNR-5095-2023'),
#                     AuthorName(display_name='Ma, Jianhui', wos_standard='Ma, JH', researcher_id='AAA-3678-2022'),
#                     AuthorName(display_name='Xie, Xing', wos_standard='Xie, X', researcher_id='IQQ-7896-2023'),
#                     AuthorName(
#                         display_name='Chen, Enhong',
#                         wos_standard='Chen, EH',
#                         researcher_id='LOL-1229-2024'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207696405029&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207696405029&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207696405029&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207696405029&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=24)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001181866502056',
#             title='HOVER: A Dataset for Many-Hop Fact Extraction And Claim Verification',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='FINDINGS OF THE ASSOCIATION FOR COMPUTATIONAL LINGUISTICS, EMNLP 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume=None,
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=20)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Jiang, Yichen',
#                         wos_standard='Jiang, YC',
#                         researcher_id='JFB-6862-2023'
#                     ),
#                     AuthorName(
#                         display_name='Bordia, Shikha',
#                         wos_standard='Bordia, S',
#                         researcher_id='GWF-6177-2022'
#                     ),
#                     AuthorName(
#                         display_name='Zhong, Zheng',
#                         wos_standard='Zhong, Z',
#                         researcher_id='GWQ-9248-2022'
#                     ),
#                     AuthorName(
#                         display_name='Dognin, Charles',
#                         wos_standard='Dognin, C',
#                         researcher_id='MKI-9214-2025'
#                     ),
#                     AuthorName(
#                         display_name='Singh, Maneesh',
#                         wos_standard='Singh, M',
#                         researcher_id='DSG-6836-2022'
#                     ),
#                     AuthorName(
#                         display_name='Bansal, Mohit',
#                         wos_standard='Bansal, M',
#                         researcher_id='Q-9105-2016'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Cohn, T'),
#                     OtherName(display_name='He, Y'),
#                     OtherName(display_name='Liu, Y')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001181866502056&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001181866502056&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001181866502056&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001181866502056&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=17)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn=None,
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-952148-90-3',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001207696403064',
#             title='Open Graph Benchmark: Datasets for Machine Learning on Graphs',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='ADVANCES IN NEURAL INFORMATION PROCESSING SYSTEMS 33, NEURIPS 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='33',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=16)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(display_name='Hu, Weihua', wos_standard='Hu, WH', researcher_id='DUQ-5873-2022'),
#                     AuthorName(
#                         display_name='Fey, Matthias',
#                         wos_standard='Fey, M',
#                         researcher_id='COU-0671-2022'
#                     ),
#                     AuthorName(
#                         display_name='Zitnik, Marinka',
#                         wos_standard='Zitnik, M',
#                         researcher_id='EIA-9697-2022'
#                     ),
#                     AuthorName(
#                         display_name='Dong, Yuxiao',
#                         wos_standard='Dong, YX',
#                         researcher_id='DTL-4687-2022'
#                     ),
#                     AuthorName(display_name='Ren, Hongyu', wos_standard='Ren, HY', researcher_id='DNK-2253-2022'),
#                     AuthorName(display_name='Liu, Bowen', wos_standard='Liu, BW', researcher_id='JCJ-5579-2023'),
#                     AuthorName(
#                         display_name='Catasta, Michele',
#                         wos_standard='Catasta, M',
#                         researcher_id='EOX-2839-2022'
#                     ),
#                     AuthorName(
#                         display_name='Leskovec, Jure',
#                         wos_standard='Leskovec, J',
#                         researcher_id='DWN-7265-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[
#                     OtherName(display_name='Larochelle, H'),
#                     OtherName(display_name='Ranzato, M'),
#                     OtherName(display_name='Hadsell, R'),
#                     OtherName(display_name='Balcan, MF'),
#                     OtherName(display_name='Lin, H')
#                 ],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001207696403064&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=W
# osAPI&KeyUT=WOS:001207696403064&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001207696403064&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001207696403064&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=4)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='1049-5258',
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-7138-2954-6',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001181866502035',
#             title='Multilingual Knowledge Graph Completion via Ensemble Knowledge Transfer',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='FINDINGS OF THE ASSOCIATION FOR COMPUTATIONAL LINGUISTICS, EMNLP 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume=None,
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range=None, begin=None, end=None, count=12)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Chen, Xuelu',
#                         wos_standard='Chen, XL',
#                         researcher_id='ISA-8699-2023'
#                     ),
#                     AuthorName(
#                         display_name='Chen, Muhao',
#                         wos_standard='Chen, MH',
#                         researcher_id='AAA-3634-2021'
#                     ),
#                     AuthorName(
#                         display_name='Fan, Changjun',
#                         wos_standard='Fan, CJ',
#                         researcher_id='LFG-7628-2024'
#                     ),
#                     AuthorName(
#                         display_name='Uppunda, Ankith',
# ...
# INTERMEDIATE LANGUAGES, VMIL 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume=None,
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range='1-1', begin='1', end='1', count=1)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Flatt, Matthew',
#                         wos_standard='Flatt, M',
#                         researcher_id='CQV-9054-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[OtherName(display_name='Feeley, M'), OtherName(display_name='Fumero, J')],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001314212800001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles=None,
#                 references=None,
#                 related=None
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=0)],
#             identifiers=DocumentIdentifiers(
#                 doi='10.1145/3427765.3432352',
#                 issn=None,
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-4503-8190-1',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(
#                 author_keywords=['Racket', 'Delimited Continuations', 'Continuation Marks', 'Threads']
#             )
#         ),
#         Document(
#             uid='WOS:001314212800003',
#             title='Understanding Graal IR (Invited Talk)',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='PROCEEDINGS OF THE 12TH ACM SIGPLAN INTERNATIONAL WORKSHOP ON VIRTUAL MACHINES AND
# INTERMEDIATE LANGUAGES, VMIL 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume=None,
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range='3-3', begin='3', end='3', count=1)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Seaton, Chris',
#                         wos_standard='Seaton, C',
#                         researcher_id='DSL-7693-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[OtherName(display_name='Feeley, M'), OtherName(display_name='Fumero, J')],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001314212800003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles=None,
#                 references=None,
#                 related=None
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=0)],
#             identifiers=DocumentIdentifiers(
#                 doi='10.1145/3427765.3432354',
#                 issn=None,
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-4503-8190-1',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=['Graal'])
#         ),
#         Document(
#             uid='WOS:001319559700065',
#             title='Visualization of Turnover Rate in a Warehouse using Augmented Reality',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='MUC 2020: PROCEEDINGS OF MENSCH UND COMPUTER 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume=None,
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range='519-522', begin='519', end='522', count=4)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Braeuer, Paula',
#                         wos_standard='Bräuer, P',
#                         researcher_id='FZV-4973-2022'
#                     ),
#                     AuthorName(
#                         display_name='Mazarakis, Athanasios',
#                         wos_standard='Mazarakis, A',
#                         researcher_id='DVP-4719-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=[OtherName(display_name='ACM')],
#                 book_editors=None,
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001319559700065&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles=None,
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001319559700065&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001319559700065&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=0)],
#             identifiers=DocumentIdentifiers(
#                 doi='10.1145/3404983.3410422',
#                 issn=None,
#                 eissn=None,
#                 isbn=None,
#                 eisbn='978-1-4503-7540-5',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(
#                 author_keywords=[
#                     'Augmented Reality',
#                     'HoloLens',
#                     'Logistics',
#                     'Warehouse',
#                     'Turnover Rate',
#                     'Visualization'
#                 ]
#             )
#         ),
#         Document(
#             uid='WOS:001323680100019',
#             title='Special Session: Algorithmic Information Dynamics',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='CELLULAR AUTOMATA AND DISCRETE COMPLEX SYSTEMS, AUTOMATA 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='12286',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range='XXII-XXIII', begin='XXII', end='XXIII', count=2)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Zenil, Hector',
#                         wos_standard='Zenil, H',
#                         researcher_id='D-6601-2013'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[OtherName(display_name='Zenil, H')],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001323680100019&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles=None,
#                 references='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI
# &KeyUT=WOS:001323680100019&DestLinkType=CitedReferences&DestApp=WOS',
#                 related='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Ke
# yUT=WOS:001323680100019&DestLinkType=RelatedRecords&DestApp=WOS_CPL'
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=0)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='0302-9743',
#                 eissn='1611-3349',
#                 isbn='978-3-030-61587-1',
#                 eisbn='978-3-030-61588-8',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001323680100012',
#             title='Constructor Theory of Life and Its Applications',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='CELLULAR AUTOMATA AND DISCRETE COMPLEX SYSTEMS, AUTOMATA 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='12286',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range='XI-XI', begin='XI', end='XI', count=1)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Marletto, Chiara',
#                         wos_standard='Marletto, C',
#                         researcher_id='GCO-9886-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[OtherName(display_name='Zenil, H')],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001323680100012&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles=None,
#                 references=None,
#                 related=None
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=0)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='0302-9743',
#                 eissn='1611-3349',
#                 isbn='978-3-030-61587-1',
#                 eisbn='978-3-030-61588-8',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001323680100017',
#             title='Isotropic Cellular Automata',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='CELLULAR AUTOMATA AND DISCRETE COMPLEX SYSTEMS, AUTOMATA 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='12286',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range='XIX-XIX', begin='XIX', end='XIX', count=1)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Wuensche, Andrew',
#                         wos_standard='Wuensche, A',
#                         researcher_id='CKH-5746-2022'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[OtherName(display_name='Zenil, H')],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001323680100017&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles=None,
#                 references=None,
#                 related=None
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=0)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='0302-9743',
#                 eissn='1611-3349',
#                 isbn='978-3-030-61587-1',
#                 eisbn='978-3-030-61588-8',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         ),
#         Document(
#             uid='WOS:001323680100013',
#             title='The Role of Emergence in Open-Ended Systems',
#             types=['Meeting'],
#             source_types=['Proceedings Paper'],
#             source=DocumentSource(
#                 source_title='CELLULAR AUTOMATA AND DISCRETE COMPLEX SYSTEMS, AUTOMATA 2020',
#                 publish_year=2020,
#                 publish_month=None,
#                 volume='12286',
#                 issue=None,
#                 supplement=None,
#                 special_issue=None,
#                 article_number=None,
#                 pages=DocumentSourcePages(range='XII-XII', begin='XII', end='XII', count=1)
#             ),
#             names=DocumentNames(
#                 authors=[
#                     AuthorName(
#                         display_name='Adams, Alyssa',
#                         wos_standard='Adams, A',
#                         researcher_id='HKW-9530-2023'
#                     )
#                 ],
#                 inventors=None,
#                 book_corp=None,
#                 book_editors=[OtherName(display_name='Zenil, H')],
#                 books=None,
#                 additional_authors=None,
#                 anonymous=None,
#                 assignees=None,
#                 corp=None,
#                 editors=None,
#                 investigators=None,
#                 sponsors=None,
#                 issuing_organizations=None
#             ),
#             links=DocumentLinks(
#                 record='https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&Key
# UT=WOS:001323680100013&DestLinkType=FullRecord&DestApp=WOS_CPL',
#                 citing_articles=None,
#                 references=None,
#                 related=None
#             ),
#             citations=[DocumentCitationsInner(db='WOS', count=0)],
#             identifiers=DocumentIdentifiers(
#                 doi=None,
#                 issn='0302-9743',
#                 eissn='1611-3349',
#                 isbn='978-3-030-61587-1',
#                 eisbn='978-3-030-61588-8',
#                 pmid=None
#             ),
#             keywords=DocumentKeywords(author_keywords=[])
#         )
#     ]
# )
