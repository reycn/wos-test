# %%
# !pip install pkgman
# !pip install git+https://github.com/clarivate/wosstarter_python_client.git

# %%
import clarivate.wos_starter.client
from pkgman import include
import time
import clarivate.wos_starter.client
from clarivate.wos_starter.client.rest import ApiException
from pprint import pprint

include(["pandas", "requests", "numpy", "tqdm", "os", "rich"])
pd = pandas
req = requests
np = numpy
os = os
pp = rich.print
tqdm = tqdm.tqdm

# %%
config_file = "../config/starter.key"
if os.path.exists(config_file):
    with open(config_file, "r") as f:
        api_key = f.read().strip()
    pp("[green bold]API key successfully loaded from config file.[/green bold]")
else:
    api_key = input("Please enter your API key: ")
    with open(config_file, "w") as f:
        f.write(api_key)
        pp("[green bold]API key saved to config file.[/green bold]")

# %%
def req_wos(
    query: str = "((DT=ARTICLE) OR (DT=Meeting) OR (DT=Proceedings Paper) OR (DT=Book) ) AND (PY=2024)",
    api_key: str = api_key,
    page: int = 1,
):
    """
    Function to make a request to the Web of Science API.
    """  # Defining the host is optional and defaults to http://api.clarivate.com/apis/wos-starter/v1

    # See configuration.py for a list of all supported configuration parameters.
    configuration = clarivate.wos_starter.client.Configuration(
        host="https://api.clarivate.com/apis/wos-starter/v1"
    )

    # The client must configure the authentication and authorization parameters
    # in accordance with the API server security policy.
    # Examples for each auth method are provided below, use the example that
    # satisfies your auth use case.

    # Configure API key authorization: ClarivateApiKeyAuth
    configuration.api_key["ClarivateApiKeyAuth"] = api_key
    ""
    # Uncomment below to setup prefix (e.g. Bearer) for API key, if needed
    # configuration.api_key_prefix['ClarivateApiKeyAuth'] = 'Bearer'

    # Enter a context with an instance of the API client
    with clarivate.wos_starter.client.ApiClient(configuration) as api_client:
        # Create an instance of the API class
        api_instance = clarivate.wos_starter.client.DocumentsApi(api_client)
        q = (
            query if query else "PY=2024"
        )  # str | Web of Science advanced [advanced search query builder](https://webofscience.help.clarivate.com/en-us/Content/advanced-search.html). The supported field tags are listed in description.
        db = "WOS"
        limit = 50  # int | set the limit of records on the page (1-50) (optional) (default to 10)
        page = page  # int | set the result page (optional) (default to 1)
        sort_field = "LD+D"  # str | Order by field(s). Field name and order by clause separated by '+', use A for ASC and D for DESC, ex: PY+D. Multiple values are separated by comma. Supported fields:  * **LD** - Load Date * **PY** - Publication Year * **RS** - Relevance * **TC** - Times Cited  (optional)
        modified_time_span = None  # str | Defines a date range in which the results were most recently modified. Beginning and end dates must be specified in the yyyy-mm-dd format separated by '+' or ' ', e.g. 2023-01-01+2023-12-31. This parameter is not compatible with the all databases search, i.e. db=WOK is not compatible with this parameter. (optional)
        tc_modified_time_span = None  # str | Defines a date range in which times cited counts were modified. Beginning and end dates must be specified in the yyyy-mm-dd format separated by '+' or ' ', e.g. 2023-01-01+2023-12-31. This parameter is not compatible with the all databases search, i.e. db=WOK is not compatible with this parameter. (optional)
        detail = None  # str | it will returns the full data by default, if detail=short it returns the limited data (optional)

        try:
            # Query Web of Science documents
            api_response = api_instance.documents_get(
                q,
                db=db,
                limit=limit,
                page=page,
                sort_field=sort_field,
                modified_time_span=modified_time_span,
                tc_modified_time_span=tc_modified_time_span,
                detail=detail,
            )
            pp("[bold green]The response of DocumentsApi->documents_get:\n[/]")
            return api_response
        except ApiException as e:
            pp(
                "[bold red][Warning] Exception when calling DocumentsApi->documents_get: %s\n[/]"
                % e
            )
            return None
        except Exception as e:
            pp(
                "[bold red][Warning] Exception when calling DocumentsApi->documents_get: %s\n[/]"
                % e
            )
            return None


def parse_wos(content, include_meta: bool = True) -> dict:
    """
    Function to parse the result of the Web of Science API request.
    """

    # =[AuthorName(display_name='Nemanov, A. D.', wos_standard='Nemanov, AD', researcher_id=None),
    def parse_wos_item(item):
        parsed_item = {}
        for prop in [
            "uid",
            "title",
            "types",
            "sourceTypes",
            "source",
            "names",
            "links",
            "citations",
            "identifiers",
            "keywords",
        ]:
            if hasattr(item, prop):
                parsed_item[prop] = getattr(item, prop)
        # [i for i in parse_wos(result)["records"][0]["names"].authors]
        if parsed_item["names"] is not None:
            if parsed_item["names"].authors is not None:
                parsed_item["authors"] = [
                    {
                        "display_name": i.display_name,
                        "wos_standard": i.wos_standard,
                        "researcher_id": i.researcher_id,
                    }
                    for i in parsed_item["names"].authors
                ]
            # del parsed_item["names"]
        if parsed_item["source"] is not None:
            parsed_item["source_title"] = parsed_item["source"].source_title
            parsed_item["year"] = parsed_item["source"].publish_year
            parsed_item["month"] = parsed_item["source"].publish_month
            parsed_item["volume"] = parsed_item["source"].volume
            parsed_item["issue"] = parsed_item["source"].issue
            parsed_item["page_range"] = parsed_item["source"].pages.range
            parsed_item["page_begin"] = parsed_item["source"].pages.begin
            parsed_item["page_end"] = parsed_item["source"].pages.end
            parsed_item["page_count"] = parsed_item["source"].pages.count
            del parsed_item["source"]
        if parsed_item["citations"] is not None:
            parsed_item["citation_count"] = parsed_item["citations"][0].count
            parsed_item["citations_db"] = parsed_item["citations"][0].db
            del parsed_item["citations"]
        if parsed_item["keywords"] is not None:
            parsed_item["keywords"] = parsed_item["keywords"].author_keywords
            del parsed_item["keywords"]
        if parsed_item["identifiers"] is not None:
            parsed_item["doi"] = parsed_item["identifiers"].doi
            parsed_item["issn"] = parsed_item["identifiers"].issn
            parsed_item["isbn"] = parsed_item["identifiers"].isbn
            parsed_item["eisbn"] = parsed_item["identifiers"].eisbn
            del parsed_item["identifiers"]
        if parsed_item["links"] is not None:
            parsed_item["link_record"] = parsed_item["links"].record
            parsed_item["link_citing"] = parsed_item["links"].citing_articles
            parsed_item["link_references"] = parsed_item["links"].references
            parsed_item["link_related"] = parsed_item["links"].related
            del parsed_item["links"]
        return parsed_item

    if not content:
        return None

    docs = {
        "records": [parse_wos_item(i) for i in content.hits],
        "meta": {
            "total": content.metadata.total,
            "limit": content.metadata.limit,
            "page": content.metadata.page,
        },
    }

    if include_meta:
        return docs
    else:
        return docs["records"]

# %%
result = req_wos()
# pp(result)
parse_wos(result)["records"][0]
# Out:
# The response of DocumentsApi->documents_get:
# {'uid': 'WOS:001429163300076',
#  'title': 'Collaborative Content Caching in IIoT: A Multi-Agent Reinforcement Learning-Based Approach',
#  'types': ['Meeting'],
#  'names': DocumentNames(authors=[AuthorName(display_name='Kang, Bingtao', wos_standard='Kang, BT', researcher_id=None), AuthorName(display_name='Peng, Kai', wos_standard='Peng, K', researcher_id=None), AuthorName(display_name='Chen, Yining', wos_standard='Chen, YN', researcher_id=None)], inventors=None, book_corp=[OtherName(display_name='IEEE COMPUTER SOC')], book_editors=None, books=None, additional_authors=None, anonymous=None, assignees=None, corp=None, editors=None, investigators=None, sponsors=None, issuing_organizations=None),
#  'authors': [{'display_name': 'Kang, Bingtao',
#    'wos_standard': 'Kang, BT',
#    'researcher_id': None},
#   {'display_name': 'Peng, Kai',
#    'wos_standard': 'Peng, K',
#    'researcher_id': None},
#   {'display_name': 'Chen, Yining',
#    'wos_standard': 'Chen, YN',
#    'researcher_id': None}],
#  'source_title': '2024 IEEE INTERNATIONAL CONFERENCE ON SMART INTERNET OF THINGS, SMARTIOT 2024',
#  'year': 2024,
#  'month': None,
#  'volume': None,
#  'issue': None,
#  'page_range': '508-515',
#  'page_begin': '508',
#  'page_end': '515',
#  'page_count': 8,
#  'citation_count': 0,
#  'citations_db': 'WOS',
#  'doi': '10.1109/SmartIoT62235.2024.00084',
#  'issn': '2770-2669',
#  'isbn': '979-8-3503-6645-7',
#  'eisbn': '979-8-3503-6644-0',
#  'link_record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&KeyUT=WOS:001429163300076&DestLinkType=FullRecord&DestApp=WOS_CPL',
#  'link_citing': None,
#  'link_references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&KeyUT=WOS:001429163300076&DestLinkType=CitedReferences&DestApp=WOS',
#  'link_related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=rongxin-test&SrcAuth=WosAPI&KeyUT=WOS:001429163300076&DestLinkType=RelatedRecords&DestApp=WOS_CPL'}

# %%
df = pd.DataFrame(parse_wos(result)["records"])
df.to_csv(
    "../data/wos.tsv",
    index=False,
    sep="\t",
    encoding="utf-8",
)
df
# Out:
#                     uid                                              title  \
# 0   WOS:001429163300076  Collaborative Content Caching in IIoT: A Multi...
# 1   WOS:001429163300022  Real-Scene 3D Urban Elements Modeling for Digi...
# 2   WOS:001424958800103  Angle-Aware Full 3D Coverage Control with ADMM...
# 3   WOS:001428150100468  Low-Intensity Pulsed Ultrasound Improved the o...
# 4   WOS:001436568400001         On the Behaviors of Fuzzy Knowledge Graphs
# 5   WOS:001428150100169  Study on Attenuation Tomography Using Low-freq...
# 6   WOS:001428150100022  Wideband Air-coupled Piezoelectric MEMS Ultras...
# 7   WOS:001432930500174  A Study of Structured Pruning for Hybrid Neura...
# 8   WOS:001423279900102  A DRL Planning Framework for Resilience of FEM...
# 9   WOS:001429153800070  Bangla SBERT - Sentence Embedding Using Multil...
# 10  WOS:001431710700089  PERCEPTUAL SKIN TONE COLOR DIFFERENCE MEASUREM...
# 11  WOS:001444006900049  Comparison of CNN Model with Different Machine...
# 12  WOS:001453642700007  Automation of Footages Sorting by Screenplay T...
# 13  WOS:001415131700028  Spatial modeling for estimating land prices of...
# 14  WOS:001428150100311  Enhancing Diverging-Wave Ultrasound Imaging wi...
# 15  WOS:001429163300035  From Radar to Depth: Multi-Modality Co-Learnin...
# 16  WOS:001428150100299  Global Constraint for Temperature Compensation...
# 17  WOS:001428150100483  Multiplying the Repetition Frequency of Optica...
# 18  WOS:001429163300052  HIGH-CONFIGURABLE WEARABLE DEVICE PLATFORM FOR...
# 19  WOS:001438533400002  Examining the Relationship Between Student Onl...
# 20  WOS:001428150100564  Compact 780 nm Rb Optical Frequency Standard o...
# 21  WOS:001431710700007             Packed Regions Information SEI Message
# 22  WOS:001429149100122  Data-Driven Short-Circuit Current Interval Pre...
# 23  WOS:001428150100499  Development and Characterization of PMUTs usin...
# 24  WOS:001428150100046  A Wide Electronically Tunable Cavity Filter Us...
# 25  WOS:001436511900018  Quality Assessment of Mobile Banking Apps with...
# 26  WOS:001429193000048         Ethical Considerations in Interoperability
# 27  WOS:001444006900055  A Decision Tree Model For Inset-Fed Microstrip...
# 28  WOS:001435013400013  Discrete-Time Sliding Mode Controller For Magn...
# 29  WOS:001431710700025  Predicting total time to compress a video corp...
# 30  WOS:001428150100502  Modeling and Imaging of GHz Ultrasonic Impedan...
# 31  WOS:001435013400009  Numerical Integrator based on Implicit Euler D...
# 32  WOS:001438533400031  Implementing Technology-Enhanced Support for F...
# 33  WOS:001428150100510  Intelligent Diagnosis of Prostate Tumors Based...
# 34  WOS:001428150100187  Non-invasive 3D Electromechanical Cycle Length...
# 35  WOS:001429193000019  Moving from the Internet of Things to the Indu...
# 36  WOS:001429153800031  Interpretable Deep Learning for Monkeypox Lesi...
# 37  WOS:001429149100119  Grid-Connected Microgrid Commitment Involving ...
# 38  WOS:001436511900007  Bridging Theory and Practice: Preparing Future...
# 39  WOS:001431710700082  MVCD: Multi-Dimensional Video Compression Dataset
# 40  WOS:001431710700102  Coarse-to-fine Transformer For Lossless 3D Med...
# 41  WOS:001435013400050  Fast-terminal Super-twisting Control for Quadr...
# 42  WOS:001423279900097  HIL Testbed-based Design and Implementation of...
# 43  WOS:001423279900026  Modeling and Validating System Dynamics in Sau...
# 44  WOS:001454824800006  Saracenical History, Containing the Acts of th...
# 45  WOS:001435620100011  Optimisation of User Interaction for the Calcu...
# 46  WOS:001429391100064  Characterization of Mesoplastic on Albanian Beach
# 47  WOS:001429163300075  Robust Fault Diagnosis for Drilling Machinery ...
# 48  WOS:001428150100262  Temperature Study of Standing Wave Ultrasonic ...
# 49  WOS:001429153800085  Supervised Learning with Informed Graph Convol...
#
#         types                                              names  \
# 0   [Meeting]  authors=[AuthorName(display_name='Kang, Bingta...
# 1   [Meeting]  authors=[AuthorName(display_name='Li, Yuejin',...
# 2   [Meeting]  authors=[AuthorName(display_name='Lu, Zhiyuan'...
# 3   [Meeting]  authors=[AuthorName(display_name='He, Min', wo...
# 4   [Meeting]  authors=[AuthorName(display_name='Ye, Yu', wos...
# 5   [Meeting]  authors=[AuthorName(display_name='Zhang, Tong'...
# 6   [Meeting]  authors=[AuthorName(display_name='Nabavi, Seye...
# 7   [Meeting]  authors=[AuthorName(display_name='Ghimire, Dee...
# 8   [Meeting]  authors=[AuthorName(display_name='Zhang, Zheng...
# 9   [Meeting]  authors=[AuthorName(display_name='Uddin, Md. S...
# 10  [Meeting]  authors=[AuthorName(display_name='Gao, Shiqi',...
# 11  [Meeting]  authors=[AuthorName(display_name='Benaouda, Wa...
# 12  [Article]  authors=[AuthorName(display_name='Nemanov, A. ...
# 13  [Meeting]  authors=[AuthorName(display_name='Wulandari, E...
# 14  [Meeting]  authors=[AuthorName(display_name='Ziksari, Mah...
# 15  [Meeting]  authors=[AuthorName(display_name='Fan, Junqiao...
# 16  [Meeting]  authors=[AuthorName(display_name='Kumar, Naren...
# 17  [Meeting]  authors=[AuthorName(display_name='Xu, Bing', w...
# 18  [Meeting]  authors=[AuthorName(display_name='Cai, Yize', ...
# 19  [Meeting]  authors=[AuthorName(display_name='Alblooshi, M...
# 20  [Meeting]  authors=[AuthorName(display_name='Yang, Qiaohu...
# 21  [Meeting]  authors=[AuthorName(display_name='Boyce, Jill'...
# 22  [Meeting]  authors=[AuthorName(display_name='Li, Xutao', ...
# 23  [Meeting]  authors=[AuthorName(display_name='Karuthedath,...
# 24  [Meeting]  authors=[AuthorName(display_name='Yang, Jie', ...
# 25  [Meeting]  authors=[AuthorName(display_name='Goceri, Mehm...
# 26  [Meeting]  authors=[AuthorName(display_name='Ferreira, Jo...
# 27  [Meeting]  authors=[AuthorName(display_name='Ouacifi, Mal...
# 28  [Meeting]  authors=[AuthorName(display_name='Pandey, Vina...
# 29  [Meeting]  authors=[AuthorName(display_name='Shu, Xin', w...
# 30  [Meeting]  authors=[AuthorName(display_name='Baskota, Anu...
# 31  [Meeting]  authors=[AuthorName(display_name='Singh, Bhawa...
# 32  [Meeting]  authors=[AuthorName(display_name='Mvunge, Nath...
# 33  [Meeting]  authors=[AuthorName(display_name='Huang, Yuzha...
# 34  [Meeting]  authors=[AuthorName(display_name='Tourni, Meli...
# 35  [Meeting]  authors=[AuthorName(display_name='Viola, Aless...
# 36  [Meeting]  authors=[AuthorName(display_name='Ahmed, Imran...
# 37  [Meeting]  authors=[AuthorName(display_name='Ye, Jichao',...
# 38  [Meeting]  authors=[AuthorName(display_name='Burris, John...
# 39  [Meeting]  authors=[AuthorName(display_name='Amirpour, Ha...
# 40  [Meeting]  authors=[AuthorName(display_name='Yang, Xiaoxu...
# 41  [Meeting]  authors=[AuthorName(display_name='Sonil, Sande...
# 42  [Meeting]  authors=[AuthorName(display_name='Yadav, Ankit...
# 43  [Meeting]  authors=[AuthorName(display_name='Alonize, Mis...
# 44  [Article]  authors=None inventors=None book_corp=None boo...
# 45  [Meeting]  authors=[AuthorName(display_name='Romero, Will...
# 46  [Meeting]  authors=[AuthorName(display_name='Claes, Yanni...
# 47  [Meeting]  authors=[AuthorName(display_name='Cai, Jijing'...
# 48  [Meeting]  authors=[AuthorName(display_name='Myint, Than ...
# 49  [Meeting]  authors=[AuthorName(display_name='Aites, L. Da...
#
#                                               authors  \
# 0   [{'display_name': 'Kang, Bingtao', 'wos_standa...
# 1   [{'display_name': 'Li, Yuejin', 'wos_standard'...
# 2   [{'display_name': 'Lu, Zhiyuan', 'wos_standard...
# 3   [{'display_name': 'He, Min', 'wos_standard': '...
# 4   [{'display_name': 'Ye, Yu', 'wos_standard': 'Y...
# 5   [{'display_name': 'Zhang, Tong', 'wos_standard...
# 6   [{'display_name': 'Nabavi, Seyedfakhreddin', '...
# 7   [{'display_name': 'Ghimire, Deepak', 'wos_stan...
# 8   [{'display_name': 'Zhang, Zhenghan', 'wos_stan...
# 9   [{'display_name': 'Uddin, Md. Shihab', 'wos_st...
# 10  [{'display_name': 'Gao, Shiqi', 'wos_standard'...
# 11  [{'display_name': 'Benaouda, Walid', 'wos_stan...
# 12  [{'display_name': 'Nemanov, A. D.', 'wos_stand...
# 13  [{'display_name': 'Wulandari, Ervika Putri', '...
# 14  [{'display_name': 'Ziksari, Mahsa Sotoodeh', '...
# 15  [{'display_name': 'Fan, Junqiao', 'wos_standar...
# 16  [{'display_name': 'Kumar, Narendra', 'wos_stan...
# 17  [{'display_name': 'Xu, Bing', 'wos_standard': ...
# 18  [{'display_name': 'Cai, Yize', 'wos_standard':...
# 19  [{'display_name': 'Alblooshi, Mardeya', 'wos_s...
# 20  [{'display_name': 'Yang, Qiaohui', 'wos_standa...
# 21  [{'display_name': 'Boyce, Jill', 'wos_standard...
# 22  [{'display_name': 'Li, Xutao', 'wos_standard':...
# 23  [{'display_name': 'Karuthedath, Cyril Baby', '...
# 24  [{'display_name': 'Yang, Jie', 'wos_standard':...
# 25  [{'display_name': 'Goceri, Mehmet Salih', 'wos...
# 26  [{'display_name': 'Ferreira, Jose', 'wos_stand...
# 27  [{'display_name': 'Ouacifi, Malika', 'wos_stan...
# 28  [{'display_name': 'Pandey, Vinay', 'wos_standa...
# 29  [{'display_name': 'Shu, Xin', 'wos_standard': ...
# 30  [{'display_name': 'Baskota, Anuj', 'wos_standa...
# 31  [{'display_name': 'Singh, Bhawana', 'wos_stand...
# 32  [{'display_name': 'Mvunge, Nathunathi', 'wos_s...
# 33  [{'display_name': 'Huang, Yuzhan', 'wos_standa...
# 34  [{'display_name': 'Tourni, Melina', 'wos_stand...
# 35  [{'display_name': 'Viola, Alessandro', 'wos_st...
# 36  [{'display_name': 'Ahmed, Imran', 'wos_standar...
# 37  [{'display_name': 'Ye, Jichao', 'wos_standard'...
# 38  [{'display_name': 'Burris, John Welsey', 'wos_...
# 39  [{'display_name': 'Amirpour, Hadi', 'wos_stand...
# 40  [{'display_name': 'Yang, Xiaoxuan', 'wos_stand...
# 41  [{'display_name': 'Sonil, Sandeep Kumar', 'wos...
# 42  [{'display_name': 'Yadav, Ankit', 'wos_standar...
# 43  [{'display_name': 'Alonize, Mishal', 'wos_stan...
# 44                                                NaN
# 45  [{'display_name': 'Romero, William A. R.', 'wo...
# 46  [{'display_name': 'Claes, Yannick', 'wos_stand...
# 47  [{'display_name': 'Cai, Jijing', 'wos_standard...
# 48  [{'display_name': 'Myint, Than Zaw', 'wos_stan...
# 49  [{'display_name': 'Aites, L. David', 'wos_stan...
#
#                                          source_title  year month volume  \
# 0   2024 IEEE INTERNATIONAL CONFERENCE ON SMART IN...  2024  None   None
# 1   2024 IEEE INTERNATIONAL CONFERENCE ON SMART IN...  2024  None   None
# 2   2024 SICE FESTIVAL WITH ANNUAL CONFERENCE, SIC...  2024  None   None
# 3   2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 4          COMPUTER APPLICATIONS, CCF NCCA 2024, PT I  2024  None   2274
# 5   2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 6   2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 7   2024 24TH INTERNATIONAL CONFERENCE ON CONTROL,...  2024  None   None
# 8   2024 56TH NORTH AMERICAN POWER SYMPOSIUM, NAPS...  2024  None   None
# 9   2024 IEEE 15TH ANNUAL UBIQUITOUS COMPUTING, EL...  2024  None   None
# 10  2024 IEEE INTERNATIONAL CONFERENCE ON VISUAL C...  2024  None   None
# 11  2024 1ST INTERNATIONAL CONFERENCE ON ELECTRICA...  2024  None   None
# 12  AUTOMATIC DOCUMENTATION AND MATHEMATICAL LINGU...  2024   DEC     58
# 13    6TH INTERNATIONAL GEOGRAPHY SEMINAR, IGEOS 2023  2024  None    600
# 14  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 15  2024 IEEE INTERNATIONAL CONFERENCE ON SMART IN...  2024  None   None
# 16  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 17  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 18  2024 IEEE INTERNATIONAL CONFERENCE ON SMART IN...  2024  None   None
# 19  PROCEEDINGS OF THE 23RD EUROPEAN CONFERENCE ON...  2024  None   23/1
# 20  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 21  2024 IEEE INTERNATIONAL CONFERENCE ON VISUAL C...  2024  None   None
# 22  2024 3RD ASIAN CONFERENCE ON FRONTIERS OF POWE...  2024  None   None
# 23  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 24  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 25  8TH INTERNATIONAL CONFERENCE ON INFORMATION SY...  2024  None   None
# 26  2024 IEEE INTERNATIONAL CONFERENCE ON ENGINEER...  2024  None   None
# 27  2024 1ST INTERNATIONAL CONFERENCE ON ELECTRICA...  2024  None   None
# 28  2024 17TH INTERNATIONAL WORKSHOP ON VARIABLE S...  2024  None   None
# 29  2024 IEEE INTERNATIONAL CONFERENCE ON VISUAL C...  2024  None   None
# 30  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 31  2024 17TH INTERNATIONAL WORKSHOP ON VARIABLE S...  2024  None   None
# 32  PROCEEDINGS OF THE 23RD EUROPEAN CONFERENCE ON...  2024  None   23/1
# 33  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 34  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 35  2024 IEEE INTERNATIONAL CONFERENCE ON ENGINEER...  2024  None   None
# 36  2024 IEEE 15TH ANNUAL UBIQUITOUS COMPUTING, EL...  2024  None   None
# 37  2024 3RD ASIAN CONFERENCE ON FRONTIERS OF POWE...  2024  None   None
# 38  8TH INTERNATIONAL CONFERENCE ON INFORMATION SY...  2024  None   None
# 39  2024 IEEE INTERNATIONAL CONFERENCE ON VISUAL C...  2024  None   None
# 40  2024 IEEE INTERNATIONAL CONFERENCE ON VISUAL C...  2024  None   None
# 41  2024 17TH INTERNATIONAL WORKSHOP ON VARIABLE S...  2024  None   None
# 42  2024 56TH NORTH AMERICAN POWER SYMPOSIUM, NAPS...  2024  None   None
# 43  2024 56TH NORTH AMERICAN POWER SYMPOSIUM, NAPS...  2024  None   None
# 44                      JOURNAL OF AFRICANA RELIGIONS  2024  None     12
# 45              ADVANCES IN COMPUTING, CCC 2024, PT I  2024  None   2208
# 46  2024 IEEE INTERNATIONAL WORKSHOP ON METROLOGY ...  2024  None   None
# 47  2024 IEEE INTERNATIONAL CONFERENCE ON SMART IN...  2024  None   None
# 48  2024 IEEE ULTRASONICS, FERROELECTRICS, AND FRE...  2024  None   None
# 49  2024 IEEE 15TH ANNUAL UBIQUITOUS COMPUTING, EL...  2024  None   None
#
#      issue  ... citation_count citations_db  \
# 0     None  ...              0          WOS
# 1     None  ...              0          WOS
# 2     None  ...              0          WOS
# 3     None  ...              0          WOS
# 4     None  ...              0          WOS
# 5     None  ...              0          WOS
# 6     None  ...              0          WOS
# 7     None  ...              0          WOS
# 8     None  ...              0          WOS
# 9     None  ...              0          WOS
# 10    None  ...              0          WOS
# 11    None  ...              0          WOS
# 12  SUPPL4  ...              0          WOS
# 13    None  ...              0          WOS
# 14    None  ...              0          WOS
# 15    None  ...              0          WOS
# 16    None  ...              0          WOS
# 17    None  ...              0          WOS
# 18    None  ...              0          WOS
# 19    None  ...              0          WOS
# 20    None  ...              0          WOS
# 21    None  ...              0          WOS
# 22    None  ...              0          WOS
# 23    None  ...              0          WOS
# 24    None  ...              0          WOS
# 25    None  ...              0          WOS
# 26    None  ...              0          WOS
# 27    None  ...              0          WOS
# 28    None  ...              0          WOS
# 29    None  ...              0          WOS
# 30    None  ...              0          WOS
# 31    None  ...              0          WOS
# 32    None  ...              0          WOS
# 33    None  ...              0          WOS
# 34    None  ...              0          WOS
# 35    None  ...              0          WOS
# 36    None  ...              0          WOS
# 37    None  ...              0          WOS
# 38    None  ...              0          WOS
# 39    None  ...              0          WOS
# 40    None  ...              0          WOS
# 41    None  ...              0          WOS
# 42    None  ...              0          WOS
# 43    None  ...              0          WOS
# 44       2  ...              0          WOS
# 45    None  ...              0          WOS
# 46    None  ...              0          WOS
# 47    None  ...              0          WOS
# 48    None  ...              0          WOS
# 49    None  ...              0          WOS
#
#                                      doi       issn               isbn  \
# 0       10.1109/SmartIoT62235.2024.00084  2770-2669  979-8-3503-6645-7
# 1       10.1109/SmartIoT62235.2024.00031  2770-2669  979-8-3503-6645-7
# 2                                   None       None  979-8-3315-4446-1
# 3     10.1109/UFFC-JS60046.2024.10794007  1099-4734  979-8-3503-7191-8
# 4            10.1007/978-981-97-9671-7_1  1865-0929  978-981-97-9670-0
# 5     10.1109/UFFC-JS60046.2024.10793704  1099-4734  979-8-3503-7191-8
# 6     10.1109/UFFC-JS60046.2024.10793501  1099-4734  979-8-3503-7191-8
# 7                                   None  2093-7121  979-8-3315-1793-9
# 8        10.1109/NAPS61145.2024.10741793  2163-4939  979-8-3315-2104-2
# 9      10.1109/UEMCON62879.2024.10754765       None  979-8-3315-4091-3
# 10       10.1109/VCIP63160.2024.10849890  2642-9357  979-8-3315-2955-0
# 11  10.1109/ECTE-TECH62477.2024.10851137       None  979-8-3503-8849-7
# 12             10.3103/S0005105525700281  0005-1055               None
# 13          10.1051/e3sconf/202460003003  2267-1242  *****************
# 14    10.1109/UFFC-JS60046.2024.10793849  1099-4734  979-8-3503-7191-8
# 15      10.1109/SmartIoT62235.2024.00044  2770-2669  979-8-3503-6645-7
# 16    10.1109/UFFC-JS60046.2024.10793837  1099-4734  979-8-3503-7191-8
# 17    10.1109/UFFC-JS60046.2024.10794022  1099-4734  979-8-3503-7191-8
# 18      10.1109/SmartIoT62235.2024.00060  2770-2669  979-8-3503-6645-7
# 19                                  None  2048-8637  978-1-917204-21-7
# 20    10.1109/UFFC-JS60046.2024.10794103  1099-4734  979-8-3503-7191-8
# 21       10.1109/VCIP63160.2024.10849788  2642-9357  979-8-3315-2955-0
# 22      10.1109/ACFPE63443.2024.10800793       None  979-8-3503-7846-7
# 23    10.1109/UFFC-JS60046.2024.10794038  1099-4734  979-8-3503-7191-8
# 24    10.1109/UFFC-JS60046.2024.10793529  1099-4734  979-8-3503-7191-8
# 25               10.1145/3686397.3686416       None               None
# 26   10.1109/ICE/ITMC61926.2024.10794291  2334-315X  979-8-3503-6244-2
# 27  10.1109/ECTE-TECH62477.2024.10851155       None  979-8-3503-8849-7
# 28        10.1109/VSS61690.2024.10753405  2158-3978  979-8-3503-5369-3
# 29       10.1109/VCIP63160.2024.10849826  2642-9357  979-8-3315-2955-0
# 30    10.1109/UFFC-JS60046.2024.10794041  1099-4734  979-8-3503-7191-8
# 31        10.1109/VSS61690.2024.10753376  2158-3978  979-8-3503-5369-3
# 32                                  None  2048-8637  978-1-917204-21-7
# 33    10.1109/UFFC-JS60046.2024.10794049  1099-4734  979-8-3503-7191-8
# 34    10.1109/UFFC-JS60046.2024.10793722  1099-4734  979-8-3503-7191-8
# 35   10.1109/ICE/ITMC61926.2024.10794235  2334-315X  979-8-3503-6244-2
# 36     10.1109/UEMCON62879.2024.10754703       None  979-8-3315-4091-3
# 37      10.1109/ACFPE63443.2024.10801089       None  979-8-3503-7846-7
# 38               10.1145/3686397.3686404       None               None
# 39       10.1109/VCIP63160.2024.10849883  2642-9357  979-8-3315-2955-0
# 40       10.1109/VCIP63160.2024.10849903  2642-9357  979-8-3315-2955-0
# 41        10.1109/VSS61690.2024.10753388  2158-3978  979-8-3503-5369-3
# 42       10.1109/NAPS61145.2024.10741783  2163-4939  979-8-3315-2104-2
# 43       10.1109/NAPS61145.2024.10741657  2163-4939  979-8-3315-2104-2
# 44           10.5325/jafrireli.12.2.0256  2165-5405               None
# 45          10.1007/978-3-031-75233-9_11  1865-0929  978-3-031-75232-2
# 46   10.1109/METROSEA62823.2024.10765627       None  979-8-3503-7901-3
# 47      10.1109/SmartIoT62235.2024.00083  2770-2669  979-8-3503-6645-7
# 48    10.1109/UFFC-JS60046.2024.10793799  1099-4734  979-8-3503-7191-8
# 49     10.1109/UEMCON62879.2024.10754727       None  979-8-3315-4091-3
#
#                 eisbn                                        link_record  \
# 0   979-8-3503-6644-0  https://www.webofscience.com/api/gateway?GWVer...
# 1   979-8-3503-6644-0  https://www.webofscience.com/api/gateway?GWVer...
# 2   978-4-9077-6483-8  https://www.webofscience.com/api/gateway?GWVer...
# 3   979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 4   978-981-97-9671-7  https://www.webofscience.com/api/gateway?GWVer...
# 5   979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 6   979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 7   978-89-93215-38-0  https://www.webofscience.com/api/gateway?GWVer...
# 8   979-8-3315-2103-5  https://www.webofscience.com/api/gateway?GWVer...
# 9   979-8-3315-4090-6  https://www.webofscience.com/api/gateway?GWVer...
# 10  979-8-3315-2954-3  https://www.webofscience.com/api/gateway?GWVer...
# 11  979-8-3503-8848-0  https://www.webofscience.com/api/gateway?GWVer...
# 12               None  https://www.webofscience.com/api/gateway?GWVer...
# 13               None  https://www.webofscience.com/api/gateway?GWVer...
# 14  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 15  979-8-3503-6644-0  https://www.webofscience.com/api/gateway?GWVer...
# 16  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 17  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 18  979-8-3503-6644-0  https://www.webofscience.com/api/gateway?GWVer...
# 19  978-1-917204-22-4  https://www.webofscience.com/api/gateway?GWVer...
# 20  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 21  979-8-3315-2954-3  https://www.webofscience.com/api/gateway?GWVer...
# 22  979-8-3503-6767-6  https://www.webofscience.com/api/gateway?GWVer...
# 23  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 24  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 25  979-8-4007-1734-5  https://www.webofscience.com/api/gateway?GWVer...
# 26  979-8-3503-6243-5  https://www.webofscience.com/api/gateway?GWVer...
# 27  979-8-3503-8848-0  https://www.webofscience.com/api/gateway?GWVer...
# 28  979-8-3503-5368-6  https://www.webofscience.com/api/gateway?GWVer...
# 29  979-8-3315-2954-3  https://www.webofscience.com/api/gateway?GWVer...
# 30  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 31  979-8-3503-5368-6  https://www.webofscience.com/api/gateway?GWVer...
# 32  978-1-917204-22-4  https://www.webofscience.com/api/gateway?GWVer...
# 33  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 34  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 35  979-8-3503-6243-5  https://www.webofscience.com/api/gateway?GWVer...
# 36  979-8-3315-4090-6  https://www.webofscience.com/api/gateway?GWVer...
# 37  979-8-3503-6767-6  https://www.webofscience.com/api/gateway?GWVer...
# 38  979-8-4007-1734-5  https://www.webofscience.com/api/gateway?GWVer...
# 39  979-8-3315-2954-3  https://www.webofscience.com/api/gateway?GWVer...
# 40  979-8-3315-2954-3  https://www.webofscience.com/api/gateway?GWVer...
# 41  979-8-3503-5368-6  https://www.webofscience.com/api/gateway?GWVer...
# 42  979-8-3315-2103-5  https://www.webofscience.com/api/gateway?GWVer...
# 43  979-8-3315-2103-5  https://www.webofscience.com/api/gateway?GWVer...
# 44               None  https://www.webofscience.com/api/gateway?GWVer...
# 45  978-3-031-75233-9  https://www.webofscience.com/api/gateway?GWVer...
# 46  979-8-3503-7900-6  https://www.webofscience.com/api/gateway?GWVer...
# 47  979-8-3503-6644-0  https://www.webofscience.com/api/gateway?GWVer...
# 48  979-8-3503-7190-1  https://www.webofscience.com/api/gateway?GWVer...
# 49  979-8-3315-4090-6  https://www.webofscience.com/api/gateway?GWVer...
#
#    link_citing                                    link_references  \
# 0         None  https://www.webofscience.com/api/gateway?GWVer...
# 1         None  https://www.webofscience.com/api/gateway?GWVer...
# 2         None  https://www.webofscience.com/api/gateway?GWVer...
# 3         None  https://www.webofscience.com/api/gateway?GWVer...
# 4         None  https://www.webofscience.com/api/gateway?GWVer...
# 5         None  https://www.webofscience.com/api/gateway?GWVer...
# 6         None  https://www.webofscience.com/api/gateway?GWVer...
# 7         None  https://www.webofscience.com/api/gateway?GWVer...
# 8         None  https://www.webofscience.com/api/gateway?GWVer...
# 9         None  https://www.webofscience.com/api/gateway?GWVer...
# 10        None  https://www.webofscience.com/api/gateway?GWVer...
# 11        None  https://www.webofscience.com/api/gateway?GWVer...
# 12        None  https://www.webofscience.com/api/gateway?GWVer...
# 13        None  https://www.webofscience.com/api/gateway?GWVer...
# 14        None  https://www.webofscience.com/api/gateway?GWVer...
# 15        None  https://www.webofscience.com/api/gateway?GWVer...
# 16        None  https://www.webofscience.com/api/gateway?GWVer...
# 17        None  https://www.webofscience.com/api/gateway?GWVer...
# 18        None  https://www.webofscience.com/api/gateway?GWVer...
# 19        None  https://www.webofscience.com/api/gateway?GWVer...
# 20        None  https://www.webofscience.com/api/gateway?GWVer...
# 21        None  https://www.webofscience.com/api/gateway?GWVer...
# 22        None  https://www.webofscience.com/api/gateway?GWVer...
# 23        None  https://www.webofscience.com/api/gateway?GWVer...
# 24        None  https://www.webofscience.com/api/gateway?GWVer...
# 25        None  https://www.webofscience.com/api/gateway?GWVer...
# 26        None  https://www.webofscience.com/api/gateway?GWVer...
# 27        None  https://www.webofscience.com/api/gateway?GWVer...
# 28        None  https://www.webofscience.com/api/gateway?GWVer...
# 29        None  https://www.webofscience.com/api/gateway?GWVer...
# 30        None  https://www.webofscience.com/api/gateway?GWVer...
# 31        None  https://www.webofscience.com/api/gateway?GWVer...
# 32        None  https://www.webofscience.com/api/gateway?GWVer...
# 33        None  https://www.webofscience.com/api/gateway?GWVer...
# 34        None  https://www.webofscience.com/api/gateway?GWVer...
# 35        None  https://www.webofscience.com/api/gateway?GWVer...
# 36        None  https://www.webofscience.com/api/gateway?GWVer...
# 37        None  https://www.webofscience.com/api/gateway?GWVer...
# 38        None  https://www.webofscience.com/api/gateway?GWVer...
# 39        None  https://www.webofscience.com/api/gateway?GWVer...
# 40        None  https://www.webofscience.com/api/gateway?GWVer...
# 41        None  https://www.webofscience.com/api/gateway?GWVer...
# 42        None  https://www.webofscience.com/api/gateway?GWVer...
# 43        None  https://www.webofscience.com/api/gateway?GWVer...
# 44        None                                               None
# 45        None  https://www.webofscience.com/api/gateway?GWVer...
# 46        None  https://www.webofscience.com/api/gateway?GWVer...
# 47        None  https://www.webofscience.com/api/gateway?GWVer...
# 48        None  https://www.webofscience.com/api/gateway?GWVer...
# 49        None  https://www.webofscience.com/api/gateway?GWVer...
#
#                                          link_related
# 0   https://www.webofscience.com/api/gateway?GWVer...
# 1   https://www.webofscience.com/api/gateway?GWVer...
# 2   https://www.webofscience.com/api/gateway?GWVer...
# 3   https://www.webofscience.com/api/gateway?GWVer...
# 4   https://www.webofscience.com/api/gateway?GWVer...
# 5   https://www.webofscience.com/api/gateway?GWVer...
# 6   https://www.webofscience.com/api/gateway?GWVer...
# 7   https://www.webofscience.com/api/gateway?GWVer...
# 8   https://www.webofscience.com/api/gateway?GWVer...
# 9   https://www.webofscience.com/api/gateway?GWVer...
# 10  https://www.webofscience.com/api/gateway?GWVer...
# 11  https://www.webofscience.com/api/gateway?GWVer...
# 12  https://www.webofscience.com/api/gateway?GWVer...
# 13  https://www.webofscience.com/api/gateway?GWVer...
# 14  https://www.webofscience.com/api/gateway?GWVer...
# 15  https://www.webofscience.com/api/gateway?GWVer...
# 16  https://www.webofscience.com/api/gateway?GWVer...
# 17  https://www.webofscience.com/api/gateway?GWVer...
# 18  https://www.webofscience.com/api/gateway?GWVer...
# 19  https://www.webofscience.com/api/gateway?GWVer...
# 20  https://www.webofscience.com/api/gateway?GWVer...
# 21  https://www.webofscience.com/api/gateway?GWVer...
# 22  https://www.webofscience.com/api/gateway?GWVer...
# 23  https://www.webofscience.com/api/gateway?GWVer...
# 24  https://www.webofscience.com/api/gateway?GWVer...
# 25  https://www.webofscience.com/api/gateway?GWVer...
# 26  https://www.webofscience.com/api/gateway?GWVer...
# 27  https://www.webofscience.com/api/gateway?GWVer...
# 28  https://www.webofscience.com/api/gateway?GWVer...
# 29  https://www.webofscience.com/api/gateway?GWVer...
# 30  https://www.webofscience.com/api/gateway?GWVer...
# 31  https://www.webofscience.com/api/gateway?GWVer...
# 32  https://www.webofscience.com/api/gateway?GWVer...
# 33  https://www.webofscience.com/api/gateway?GWVer...
# 34  https://www.webofscience.com/api/gateway?GWVer...
# 35  https://www.webofscience.com/api/gateway?GWVer...
# 36  https://www.webofscience.com/api/gateway?GWVer...
# 37  https://www.webofscience.com/api/gateway?GWVer...
# 38  https://www.webofscience.com/api/gateway?GWVer...
# 39  https://www.webofscience.com/api/gateway?GWVer...
# 40  https://www.webofscience.com/api/gateway?GWVer...
# 41  https://www.webofscience.com/api/gateway?GWVer...
# 42  https://www.webofscience.com/api/gateway?GWVer...
# 43  https://www.webofscience.com/api/gateway?GWVer...
# 44                                               None
# 45  https://www.webofscience.com/api/gateway?GWVer...
# 46  https://www.webofscience.com/api/gateway?GWVer...
# 47  https://www.webofscience.com/api/gateway?GWVer...
# 48  https://www.webofscience.com/api/gateway?GWVer...
# 49  https://www.webofscience.com/api/gateway?GWVer...
#
# [50 rows x 24 columns]
